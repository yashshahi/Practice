# %% [markdown]
# ### Introduction to streamlit
# ***
#
# streamlit is an opens source app framework for Machine Learning and Data science project it allows you to create beautiful web applications for your machine learning and data science projects with simple python scripts.
