# %% [markdown]
# ## Flask Framework
# ***
#
# 1. WSGI:web server gateway interface
# 2. Jinja2 :template engine
#
# * Flask: web framework created with using python programming language
#
# * combining a layout of a page with data source it help us to create dynamic webpages
